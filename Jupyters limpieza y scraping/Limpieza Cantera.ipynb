# %%
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set({"figure.figsize":(22,15)})
sns.set(font_scale = 1.15)
import plotly.express as px
import seaborn as sns
import pandas as pd
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %%
rmd7 = pd.read_csv("../../Data/f7Real.csv",encoding = "ISO-8859-1")

# %%
fcb7 = pd.read_csv("../../Data/f7Barça.csv",encoding = "ISO-8859-1")

# %%
rmd = pd.read_csv("../../Data/f7Real.csv",encoding = "ISO-8859-1")

# %%
fcb = pd.read_csv("../../Data/Barça.csv",encoding = "ISO-8859-1")

# %%
rmd['Equipo'] = 'RMD'
rmd7['Equipo'] = 'RMD'
fcb['Equipo'] = 'FCB'
fcb7['Equipo'] = 'FCB'

# %%
cantera = pd.concat([rmd, fcb], axis=0)

# %%
cantera7 = pd.concat([rmd7, fcb7], axis=0)

# %%
cantera7.head(1)
# Out:
#    Unnamed: 0                   Nombre  Nacimiento    Categoria  year  month  \
# 0           0  Samuel AlcÃ¡zar MartÃ­n  08/07/2015  Prebenjamin  2015      8
#
#    day  trimestre Equipo
# 0    7          3    RMD

# %%
cantera.to_csv('../../Data/cantera.csv', encoding='utf-8')

# %%
cantera7.to_csv('../../Data/cantera7.csv', encoding='utf-8')

# %%
ax = sns.barplot(x="month", y="month", data=cantera, estimator=lambda x: len(x) / len(cantera) * 100) 
ax.set(ylabel="Percent")
# Out:
# [Text(0, 0.5, 'Percent')]

# %%
ax = sns.barplot(x="trimestre", y="trimestre", data=cantera, estimator=lambda x: len(x) / len(cantera) * 100) 
ax.set(ylabel="Percent")
# Out:
# [Text(0, 0.5, 'Percent')]

# %%
a = cantera.loc[cantera["year"] == 2012]

# %%
a.head(3)
# Out:
#     Unnamed: 0                       Nombre  Nacimiento Categoria  year  \
# 31          10        Lucas GÃ³mez SaldaÃ±a  09/01/2012  Benjamin  2012
# 32          11  Guillermo Cubero FernÃ¡ndez  14/01/2012  Benjamin  2012
# 33          12         RubÃ©n Mallo Ãlices  04/01/2012  Benjamin  2012
#
#     month  day  trimestre Equipo
# 31      9    1          3    RMD
# 32      1   14          1    RMD
# 33      4    1          2    RMD

# %%
ax = sns.barplot(x="month", y="month", data=a, estimator=lambda x: len(x) / len(a) * 100) 
ax.set(ylabel="Percent")
# Out:
# [Text(0, 0.5, 'Percent')]

# %%
ax = sns.countplot(x="month", data=a)

# %%
ax = sns.countplot(x="month", data=cantera7)

# %%
datos = cantera["trimestre"].value_counts()
datos
# Out:
# 1    167
# 2     83
# 3     50
# 4     33
# Name: trimestre, dtype: int64

# %%
datos.plot.pie(autopct="%.1f%%")
# Out:
# <AxesSubplot:ylabel='trimestre'>
