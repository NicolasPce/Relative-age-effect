# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set({"figure.figsize":(22,15)})
sns.set(font_scale = 1.15)
import seaborn as sns

# %%
df = pd.read_csv("../../Data/ajedrecistas.csv",encoding = "ISO-8859-1")

# %%
df = df.loc[df["PaÃ­s"] != "United States"]
df = df.loc[df["PaÃ­s"] != "England"]

# %%
ax = sns.barplot(x="trimestre", y="trimestre", data=df, estimator=lambda x: len(x) / len(df) * 100) 
ax.set(ylabel="Percent")
# Out:
# [Text(0, 0.5, 'Percent')]

# %%
df.to_csv('../../Data/ajedrezfinal.csv', encoding='utf-8')
