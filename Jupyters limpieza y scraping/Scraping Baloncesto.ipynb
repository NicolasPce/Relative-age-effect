# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager

# %%
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)


opciones.binary_location = "/Applications/Google Chrome.app/Contents/MacOS/Google Chrome"
chrome_driver_binary = "/usr/local/bin/chromedriver"

opciones.headless=False    # si True, no aperece la ventana (headless=no visible)


opciones.add_argument("--start-maximized")         # comienza maximizado

opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies

#opciones.add_extension('driver_folder/adblock.crx')       # adblocker

opciones.add_argument('--incognito')              # incognito
#modal-policy > ul > li:nth-child(1) > button

# %%
# download the driver 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)

# set the url
url2 = "https://es.wikipedia.org/w/index.php?title=Categor%C3%ADa:Baloncestistas_de_la_selección_de_España&pageuntil=Riera+%2C+Joan%0AJoan+Riera+%28baloncestista+catalán%29#mw-pages"

nombre = []
edad = []

# request the url
driver.get(url2)

driver.implicitly_wait(500) # is like a time.sleep but specific of selenium


for i in range (1,23):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(1) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")   

for i in range (1,20):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(2) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")

for i in range (1,20):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(3) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")

for i in range (1,13):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(4) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")    
    
for i in range (1,8):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(5) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")    
    
for i in range (1,9):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(6) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)") 
    
for i in range (1,21):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(7) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")     
    
for i in range (1,6):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(8) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")  
    
for i in range (1,5):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(9) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")  
    
for i in range (1,6):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(10) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")

    
for i in range (1,3):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(11) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")  
    
for i in range (1,19):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(12) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)") 
    
    
for i in range (1,30):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(13) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")     
    
for i in range (1,5):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(14) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)") 
    
for i in range (1,4):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(15) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")
    
for i in range (1,13):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(16) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")  
    
for i in range (1,8):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(17) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/macniacos/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-204-7539c7d2e387>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-204-7539c7d2e387>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(1) > ul > li:nth-child({i}) > a").click()
# <ipython-input-204-7539c7d2e387>:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
# ...

# %%
# download the driver 
driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)

# set the url
url2 = "https://es.wikipedia.org/w/index.php?title=Categor%C3%ADa:Baloncestistas_de_la_selección_de_España&pagefrom=Riera+%2C+Joan%0AJoan+Riera+%28baloncestista+catalán%29#mw-pages"

# request the url
driver.get(url2)

driver.implicitly_wait(500) # is like a time.sleep but specific of selenium


for i in range (1,18):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(1) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")   

for i in range (1,24):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(2) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")

for i in range (1,5):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(3) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")

for i in range (1,2):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(4) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")    
    
for i in range (1,11):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(5) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")    
    
for i in range (1,2):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(6) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)") 
    
for i in range (1,2):
    
    driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(7) > ul > li:nth-child({i}) > a").click()  
    nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
    edad.append(driver.find_element_by_css_selector(f"#mw-content-text > div.mw-parser-output > table").text)
    driver.execute_script("window.history.go(-1)")
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [/Users/macniacos/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache
# <ipython-input-205-5cb9b18aae3b>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), options = opciones)
# <ipython-input-205-5cb9b18aae3b>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_css_selector(f"#mw-pages > div > div > div:nth-child(1) > ul > li:nth-child({i}) > a").click()
# <ipython-input-205-5cb9b18aae3b>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   nombre.append(driver.find_element_by_css_selector(f"#firstHeading").text)
# ...

# %%
len(nombre)
# Out:
# 253

# %%
nombre
# Out:
# ['Santi Abad',
#  'Alberto Abalde Díaz',
#  'Pablo Aguilar Bermúdez',
#  'Alfonso Albert',
#  'Santiago Aldama',
#  'Manuel Aller',
#  'Carlos Alocén',
#  'Lorenzo Alocén',
#  'Emilio Alonso Arbeleche',
#  'Pedro Alonso Arbeleche',
#  'José Gabriel Álvarez (baloncestista)',
#  'Luis Miguel Álvarez',
#  'Quique Andreu',
#  'Alberto Angulo',
#  'Lucio Angulo',
#  'Pedro Ansa',
#  'José Miguel Antúnez',
#  'Fernando Arcega',
#  'José Ángel Arcega Aperte',
#  'Víctor Arteaga',
#  'Artur Auladell',
#  'Nacho Azofra',
#  'Domingo Bárcenas',
#  'Jonathan Barreiro',
#  'Ferrán Bassas',
#  'Jaume Bassó',
#  'Javier Beirán',
#  'José Manuel Beirán',
#  'José Luis Beltrán Lassaletta',
#  'Agustín Bertomeu',
#  'Jordi Bonareu',
#  'Freddy Borrás',
#  'Francisco Borrell',
#  'Manel Bosch',
#  'Manuel Bosch',
#  'Wayne Brabender',
#  'Darío Brizuela',
#  'Josep Brunet',
#  'Antonio Bueno',
#  'Francesc Buscató',
#  'Silvano Bustos',
#  'Carlos Cabezas',
#  'José Manuel Calderón',
# ...

# %%
len(edad)
# Out:
# 253

# %%
test = edad

# %%
prueba = edad[160]

# %%
prueba
# Out:
# 'Albert Miralles\nDatos personales\nNombre completo Alberto Miralles Berge\nNacimiento Barcelona, España  España\n14 de mayo de 1982\nNacionalidad(es) Española\nAltura 2,06 m\nCarrera deportiva\nDeporte Baloncesto\nClub profesional\nDraft 2ª ronda (puesto 39) 2004 por Toronto Raptors1\nClub Retirado\nPosición Pívot\nDorsal(es) 10\nSelección nacional\nSelección España\nPart. 5\n              Medallero\n[mostrar]\n[editar datos en Wikidata]'

# %%
prueba.split(" (")[0]
# Out:
# 'Joan Dalmau\nDatos personales\nNombre completo Joan Dalmau\nApodo(s) "El gato"\nNacimiento Montgat, Barcelona  España\n22 de agosto de 1924\nNacionalidad(es) Española\nFallecimiento 17 de agosto de 2006\nCarrera deportiva\nDeporte Baloncesto\nClub profesional\nClub Retirado\nLiga Liga Española\nSelección nacional\nSelección España\nPart. 38\n              Medallero\n[mostrar]\n[editar datos en Wikidata]'

# %%
a = prueba.split("\n")[5]

# %%
a
# Out:
# 'Nacionalidad(es) Española'

# %%
a.split(" (")[0]
# Out:
# 'Datos personales'

# %%
edad1 = [i.split(" (")[0] for i in test]

# %%
edad2 = [i.split("\n")[1] for i in edad1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-239-a5e32ee829e5> in <module>
# ----> 1 edad2 = [i.split("\n")[1] for i in edad1]
#
# <ipython-input-239-a5e32ee829e5> in <listcomp>(.0)
# ----> 1 edad2 = [i.split("\n")[1] for i in edad1]
#
# IndexError: list index out of range

# %%
edad1[218]
# Out:
# 'Álvaro Salvadores\n\nJohn Stanich'

# %%
edad2[4]
# Out:
# 'tiago Aldama\nDatos perso'

# %%
edad
# Out:
# ['Santi Abad\nDatos personales\nNombre completo Santiago Abad Viciano\nNacimiento Barcelona, España\n24 de julio de 1969 (52 años)\nNacionalidad(es)  España\nAltura 2,03 m (6 ′ 8 ″)\nCarrera deportiva\nDeporte Baloncesto\nClub profesional\nClub Retirado\nLiga ACB\nPosición Ala-Pívot\nDorsal(es) 9\nSelección nacional\nSelección España\nPart. 16\n[editar datos en Wikidata]',
# ...

# %%
edad1
# Out:
# ['Santi Abad\nDatos personales\nNombre completo Santiago Abad Viciano\nNacimiento Barcelona, España\n24 de julio de 1969',
#  'Alberto Abalde\nDatos personales\nNombre completo Alberto Abalde Díaz\nNacimiento Ferrol, La Coruña  España\n15 de diciembre de 1995',
#  'Pablo Aguilar\nDatos personales\nNombre completo Pablo Aguilar Bermúdez\nNacimiento Granada, Andalucía\n09 de febrero de 1989',
#  'Alfonso Albert\nDatos personales\nNombre completo Alfonso Albert García\nNacimiento Torrent, Valencia  España\n22 de mayo de 1973',
#  'Santiago Aldama\nDatos personales\nNombre completo Santiago Aldama Alesón\nApodo(s) Aldama\nNacimiento Quel, La Rioja,  España\n7 de diciembre de 1968',
#  'Manuel Aller\nDatos personales\nNombre completo Manuel Ángel Aller Carballo\nNacimiento Ponferrada, León,  España\n17 de abril de 1963',
# ...
