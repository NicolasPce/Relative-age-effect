# %%
import numpy as np
import datetime
import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set({"figure.figsize":(22,15)})
sns.set(font_scale = 1.15)
import plotly.express as px
import seaborn as sns
import pandas as pd
import plotly.graph_objects as go
import matplotlib.pyplot as plt

# %%
a = pd.read_csv("../../Data/diputados19.csv",encoding = "ISO-8859-1")
b = pd.read_csv("../../Data/diputados00.csv",encoding = "ISO-8859-1")

# %%
df = pd.concat([a, b], axis=0)

# %%
df.head(3)
# Out:
#    Unnamed: 0                      Nombre  Nacimiento  year  month  day  \
# 0           0    Ãbalos Meco, JosÃ© Luis  09/12/1959  1959      9   12
# 1           1     Abascal Conde, Santiago  14/04/1976  1976      4   14
# 2           2  Aceves Galindo, JosÃ© Luis  21/05/1970  1970      5   21
#
#    trimestre
# 0          3
# 1          2
# 2          2

# %%
ax = sns.barplot(x="trimestre", y="trimestre", data=df, estimator=lambda x: len(x) / len(df) * 100) 
ax.set(ylabel="Percent")
# Out:
# [Text(0, 0.5, 'Percent')]

# %%
df.to_csv('../../Data/diputadosfinal.csv', encoding='utf-8')
